# %% [markdown]
# # 01 Streaming 2.5D Cache Builder
#
# Inputs:
#
# - output dataset from notebook `00_archive_listing_manifest.ipynb`
# - the three raw no-autoextract ViMed-PET Kaggle datasets
#
# This notebook creates a memory-safe 2.5D cache without extracting an
# entire source base. It extracts CT/PET files in small batches, converts
# each case into six `uint8` channels, flushes the memmap cache, and removes
# temporary raw arrays after every batch.
#
# The notebook is resumable. If Kaggle disconnects, rerun with the previous
# output attached and already cached case ids will be skipped.

# %%
from pathlib import Path
import os, re, json, shutil, subprocess, warnings, time
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

warnings.filterwarnings("ignore")

OUTPUT_ROOT = Path("/kaggle/working/vimedpet_q1_outputs") if Path("/kaggle/working").exists() else Path("vimedpet_q1_outputs")
CACHE_DIR = OUTPUT_ROOT / "01_cache"
CACHE_DIR.mkdir(parents=True, exist_ok=True)
SCRATCH_ROOT = Path("/kaggle/temp/vimedpet_q1_cache_stream") if Path("/kaggle").exists() else OUTPUT_ROOT / "_scratch_cache_stream"
STAGE_ROOT = SCRATCH_ROOT / "archive_stage"
BATCH_ROOT = SCRATCH_ROOT / "batch_extract"

for p in [SCRATCH_ROOT, STAGE_ROOT, BATCH_ROOT]:
    if p.exists():
        shutil.rmtree(p, ignore_errors=True)
    p.mkdir(parents=True, exist_ok=True)

IMAGE_SIZE = 224
CHANNELS_25D = 6
BATCH_CASES_PER_EXTRACT = 6
# Use None for full cache. For a quick smoke run, set for example 120.
CACHE_CASE_LIMIT = None
# Use None for all splits. To validate quickly first: ["validation", "test"].
CACHE_ONLY_SPLITS = None
RESUME_FROM_EXISTING = True

INPUT_HINTS = [
    "/kaggle/input/datasets/tundng111/vimed-pet-ct-part1-raw-no-autoextract-v3",
    "/kaggle/input/datasets/tundng111/vimed-pet-ct-part2-raw-no-autoextract-v1",
    "/kaggle/input/datasets/tundng111/vimed-pet-ct-part3-raw-no-autoextract-v1",
    "/kaggle/input",
    str(Path.cwd()),
]

def show_disk_usage(label):
    print(f"\nDisk usage: {label}")
    for raw_path in ["/kaggle/temp", "/tmp", "/kaggle/working"]:
        p = Path(raw_path)
        if p.exists():
            usage = shutil.disk_usage(p)
            print(raw_path, "free GiB:", round(usage.free / 1024**3, 2), "used GiB:", round(usage.used / 1024**3, 2), "total GiB:", round(usage.total / 1024**3, 2))

print("OUTPUT_ROOT:", OUTPUT_ROOT)
print("CACHE_DIR:", CACHE_DIR)
print("SCRATCH_ROOT:", SCRATCH_ROOT)
show_disk_usage("after setup")

def import_previous_cache_if_available():
    if not Path("/kaggle/input").exists():
        return
    if (CACHE_DIR / "q1_cache_meta.json").exists() and (CACHE_DIR / "q1_cache_index.csv").exists():
        return
    candidates = sorted(Path("/kaggle/input").rglob("q1_cache_meta.json"), key=lambda p: len(str(p)))
    for meta_path in candidates:
        src_dir = meta_path.parent
        try:
            meta = json.loads(meta_path.read_text(encoding="utf-8"))
        except Exception:
            continue
        mmap_name = meta.get("mmap_path")
        required = [src_dir / "q1_cache_index.csv", src_dir / "q1_clean_manifest_for_cache.csv", src_dir / str(mmap_name)]
        if not mmap_name or not all(p.exists() for p in required):
            continue
        print("Importing previous cache from:", src_dir)
        for p in required + [meta_path]:
            dst = CACHE_DIR / p.name
            if not dst.exists():
                shutil.copy2(p, dst)
        return

import_previous_cache_if_available()
# Out:
# OUTPUT_ROOT: /kaggle/working/vimedpet_q1_outputs
# CACHE_DIR: /kaggle/working/vimedpet_q1_outputs/01_cache
# SCRATCH_ROOT: /kaggle/temp/vimedpet_q1_cache_stream
#
# Disk usage: after setup
# /kaggle/temp free GiB: 1065.08 used GiB: 6997.29 total GiB: 8062.39
# /tmp free GiB: 1065.08 used GiB: 6997.29 total GiB: 8062.39
# /kaggle/working free GiB: 19.5 used GiB: 0.0 total GiB: 19.52

# %%
def locate_clean_manifest():
    roots = []
    if Path("/kaggle/input").exists():
        roots += list(Path("/kaggle/input").rglob("q1_clean_manifest.csv"))
    roots += list(Path.cwd().rglob("q1_clean_manifest.csv"))
    roots = [p for p in roots if "01_cache" not in str(p)]
    if not roots:
        raise FileNotFoundError("q1_clean_manifest.csv not found. Attach notebook 00 output as input.")
    return sorted(roots, key=lambda p: len(str(p)))[0]

def clean_value(x):
    s = "" if pd.isna(x) else str(x).strip()
    if s.lower() in {"nan", "none", "null"}:
        return ""
    return re.sub(r"\s+", " ", s)

def build_model_target(row):
    findings = clean_value(row.get("findings", ""))
    impression = clean_value(row.get("impression", ""))
    parts = []
    if findings:
        parts.append("FINDINGS:\n" + findings)
    if impression:
        parts.append("IMPRESSION:\n" + impression)
    target = "\n\n".join(parts).strip()
    if not target:
        target = clean_value(row.get("report_text_clean", row.get("target_text", "")))
    return target

manifest_path = locate_clean_manifest()
clean = pd.read_csv(manifest_path)
clean = clean.reset_index(drop=True)
clean["row_index"] = np.arange(len(clean), dtype=np.int64)
if CACHE_ONLY_SPLITS is not None:
    clean = clean[clean["clean_split"].isin(CACHE_ONLY_SPLITS)].copy()
if CACHE_CASE_LIMIT is not None:
    clean = clean.head(CACHE_CASE_LIMIT).copy()

clean["model_target_text"] = clean.apply(build_model_target, axis=1)
clean["target_text"] = clean["model_target_text"]
section_check = pd.DataFrame([
    {"field": "findings", "present": int(clean["findings"].fillna("").astype(str).str.strip().ne("").sum())},
    {"field": "impression", "present": int(clean["impression"].fillna("").astype(str).str.strip().ne("").sum())},
    {"field": "model_target_has_impression", "present": int(clean["model_target_text"].str.contains("IMPRESSION:", regex=False).sum())},
])
section_check["total"] = int(len(clean))
section_check["coverage"] = section_check["present"] / section_check["total"].clip(lower=1)
section_check["coverage_percent"] = (section_check["coverage"] * 100).round(2)

print("Manifest:", manifest_path)
print("Rows selected:", clean.shape)
display(clean.groupby("clean_split").size().rename("cases").reset_index())
display(clean.groupby("source_part").size().rename("cases").reset_index())
display(Markdown("### Target section coverage used for cache/modeling"))
display(section_check)
assert float(section_check.loc[section_check.field == "impression", "coverage"].iloc[0]) >= 0.90, section_check
assert float(section_check.loc[section_check.field == "model_target_has_impression", "coverage"].iloc[0]) >= 0.90, section_check
# Out:
# Manifest: /kaggle/input/notebooks/hannhu4002/00-archive-listing-manifest-cleaning-and-split/vimedpet_q1_outputs/00_manifest/q1_clean_manifest.csv
# Rows selected: (2757, 43)
#   clean_split  cases
# 0        test    413
# 1       train   1931
# 2  validation    413
#     source_part  cases
# 0    PETCT_2017    215
# 1    PETCT_2018    462
# 2    PETCT_2019    339
# 3  PETCT_2023_1    502
# 4  PETCT_2023_2    762
# 5  PETCT_2023_3    477
# ### Target section coverage used for cache/modeling
#                          field  present  total  coverage  coverage_percent
# 0                     findings     2756   2757  0.999637             99.96
# 1                   impression     2730   2757  0.990207             99.02
# 2  model_target_has_impression     2730   2757  0.990207             99.02

# %%
def existing_roots():
    roots = []
    for x in INPUT_HINTS:
        p = Path(x)
        if p.exists():
            roots.append(p)
    seen, out = set(), []
    for r in roots:
        rr = r.resolve()
        if rr not in seen:
            out.append(rr)
            seen.add(rr)
    return out

def sevenzip_binary():
    for exe in ["7z", "7zz", "7za"]:
        try:
            subprocess.run([exe], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
            return exe
        except Exception:
            continue
    raise RuntimeError("7z/7zz/7za not found")

def find_archive_group(source_base):
    hits = []
    for root in existing_roots():
        for marker in list(root.rglob(f"{source_base}.zipraw")) + list(root.rglob(f"{source_base}.zip")):
            parts = sorted(marker.parent.glob(f"{source_base}.z[0-9][0-9]"))
            hits.append({"marker": marker, "parts": parts, "folder": marker.parent})
    if not hits:
        raise FileNotFoundError(f"Archive marker not found for {source_base}")
    return sorted(hits, key=lambda h: len(h["parts"]), reverse=True)[0]

def symlink_required(src, dst):
    if dst.exists() or dst.is_symlink():
        dst.unlink()
    try:
        os.symlink(src, dst)
    except Exception as exc:
        raise RuntimeError("Symlink failed; copying archives is intentionally disabled to protect temp disk.") from exc

def stage_archive(source_base, group):
    stage = STAGE_ROOT / source_base
    if stage.exists():
        shutil.rmtree(stage, ignore_errors=True)
    stage.mkdir(parents=True, exist_ok=True)
    names = [p.name for p in group["parts"]]
    expected = [f"{source_base}.z{i:02d}" for i in range(1, len(group["parts"]) + 1)]
    missing = [x for x in expected if x not in names]
    if missing:
        raise FileNotFoundError(f"Missing split volumes for {source_base}: {missing}")
    for part in group["parts"]:
        symlink_required(part, stage / part.name)
    symlink_required(group["marker"], stage / f"{source_base}.zip")
    print(f"{source_base}: parts={len(group['parts'])}, marker={group['marker'].name}")
    return stage / f"{source_base}.zip"

def run_7z_extract(zip_path, out_dir, archive_paths):
    if out_dir.exists():
        shutil.rmtree(out_dir, ignore_errors=True)
    out_dir.mkdir(parents=True, exist_ok=True)
    cmd = [sevenzip_binary(), "x", str(zip_path), f"-o{out_dir}", "-y"] + list(archive_paths)
    result = subprocess.run(cmd, text=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    if result.returncode != 0:
        print(result.stdout[-2000:])
        raise RuntimeError("7z batch extraction failed")
    return out_dir

# %%
def resize_u8(x, size=IMAGE_SIZE):
    return np.asarray(Image.fromarray(x).resize((size, size), Image.BILINEAR), dtype=np.uint8)

def normalize_uint8(x, lo=None, hi=None):
    x = np.asarray(x, dtype=np.float32)
    if lo is None:
        lo = float(np.nanpercentile(x, 1))
    if hi is None:
        hi = float(np.nanpercentile(x, 99))
    x = np.clip(x, lo, hi)
    return ((x - lo) / max(hi - lo, 1e-6) * 255).astype(np.uint8)

def sample_slice(vol, frac):
    z = vol.shape[0]
    idx = min(max(int(round((z - 1) * frac)), 0), z - 1)
    return np.asarray(vol[idx])

def make_25d(ct, pet):
    ct35 = resize_u8(normalize_uint8(sample_slice(ct, 0.35), -1000, 1000))
    ct50 = resize_u8(normalize_uint8(sample_slice(ct, 0.50), -1000, 1000))
    ct65 = resize_u8(normalize_uint8(sample_slice(ct, 0.65), -1000, 1000))
    pet_arr = np.asarray(pet)
    pet_ax = resize_u8(normalize_uint8(pet_arr.max(axis=0)))
    pet_cor = resize_u8(normalize_uint8(pet_arr.max(axis=1)))
    pet_sag = resize_u8(normalize_uint8(pet_arr.max(axis=2)))
    return np.stack([ct35, ct50, ct65, pet_ax, pet_cor, pet_sag], axis=0)

def batch_iter(df, n):
    rows = df.to_dict("records")
    for i in range(0, len(rows), n):
        yield rows[i:i+n]

# %%
n_total = int(clean["row_index"].max()) + 1
mmap_path = CACHE_DIR / f"q1_25d_uint8_{IMAGE_SIZE}.memmap"
if mmap_path.exists():
    arr = np.memmap(mmap_path, dtype=np.uint8, mode="r+", shape=(n_total, CHANNELS_25D, IMAGE_SIZE, IMAGE_SIZE))
else:
    arr = np.memmap(mmap_path, dtype=np.uint8, mode="w+", shape=(n_total, CHANNELS_25D, IMAGE_SIZE, IMAGE_SIZE))

cache_index_path = CACHE_DIR / "q1_cache_index.csv"
if RESUME_FROM_EXISTING and cache_index_path.exists():
    cache_index = pd.read_csv(cache_index_path)
    done_cases = set(cache_index.loc[cache_index["cache_ok"] == True, "case_id"].astype(str))
    cache_rows = cache_index.to_dict("records")
else:
    done_cases = set()
    cache_rows = []

selected = clean[~clean["case_id"].astype(str).isin(done_cases)].copy()
print("Already cached:", len(done_cases), "remaining:", len(selected))

start_time = time.time()
source_order = selected["source_part"].drop_duplicates().tolist()
for source_base in source_order:
    group_df = selected[selected["source_part"] == source_base].copy()
    archive_group = find_archive_group(source_base)
    zip_path = stage_archive(source_base, archive_group)
    try:
        for batch_no, batch in enumerate(batch_iter(group_df, BATCH_CASES_PER_EXTRACT), start=1):
            batch_dir = BATCH_ROOT / source_base / f"batch_{batch_no:05d}"
            archive_paths = []
            for row in batch:
                archive_paths.append(row["ct_path"])
                archive_paths.append(row["pet_path"])
            show_disk_usage(f"before {source_base} batch {batch_no}")
            run_7z_extract(zip_path, batch_dir, archive_paths)

            new_rows = []
            for row in batch:
                try:
                    ct_file = batch_dir / row["ct_path"]
                    pet_file = batch_dir / row["pet_path"]
                    ct = np.load(ct_file, mmap_mode="r")
                    pet = np.load(pet_file, mmap_mode="r")
                    arr[int(row["row_index"])] = make_25d(ct, pet)
                    ok, err = True, ""
                    ct_shape, pet_shape = str(tuple(ct.shape)), str(tuple(pet.shape))
                except Exception as exc:
                    ok, err = False, str(exc)
                    ct_shape, pet_shape = "", ""
                rec = {
                    "row_index": int(row["row_index"]),
                    "case_id": row["case_id"],
                    "source_part": source_base,
                    "clean_split": row["clean_split"],
                    "ct_path": row["ct_path"],
                    "pet_path": row["pet_path"],
                    "cache_ok": ok,
                    "cache_error": err,
                    "ct_shape": ct_shape,
                    "pet_shape": pet_shape,
                }
                cache_rows.append(rec)
                new_rows.append(rec)
            arr.flush()
            pd.DataFrame(cache_rows).drop_duplicates("case_id", keep="last").to_csv(cache_index_path, index=False, encoding="utf-8-sig")
            shutil.rmtree(batch_dir, ignore_errors=True)
            ok_count = sum(1 for r in new_rows if r["cache_ok"])
            elapsed = (time.time() - start_time) / 60
            print(f"{source_base} batch {batch_no}: cached {ok_count}/{len(new_rows)} cases, elapsed {elapsed:.1f} min")
            show_disk_usage(f"after cleanup {source_base} batch {batch_no}")
    finally:
        shutil.rmtree(STAGE_ROOT / source_base, ignore_errors=True)
        shutil.rmtree(BATCH_ROOT / source_base, ignore_errors=True)

cache_index = pd.DataFrame(cache_rows).drop_duplicates("case_id", keep="last")
cache_index.to_csv(cache_index_path, index=False, encoding="utf-8-sig")
clean.to_csv(CACHE_DIR / "q1_clean_manifest_for_cache.csv", index=False, encoding="utf-8-sig")

meta = {
    "image_size": IMAGE_SIZE,
    "channels": CHANNELS_25D,
    "n": n_total,
    "mmap_path": mmap_path.name,
    "source_manifest": str(manifest_path),
    "cache_case_limit": CACHE_CASE_LIMIT,
    "cache_only_splits": CACHE_ONLY_SPLITS,
    "batch_cases_per_extract": BATCH_CASES_PER_EXTRACT,
    "target_column": "model_target_text",
}
(CACHE_DIR / "q1_cache_meta.json").write_text(json.dumps(meta, ensure_ascii=False, indent=2), encoding="utf-8")

display(cache_index.groupby(["clean_split", "cache_ok"]).size().rename("cases").reset_index())
val_test = cache_index[cache_index["clean_split"].isin(["validation", "test"])]
if CACHE_ONLY_SPLITS is None or set(CACHE_ONLY_SPLITS) & {"validation", "test"}:
    assert len(val_test) > 0 and val_test["cache_ok"].all(), "Validation/test cache must be complete before final evaluation"
print("Saved cache:", CACHE_DIR)
# Out:
# Already cached: 0 remaining: 2757
# PETCT_2017: parts=6, marker=PETCT_2017.zipraw
#
# Disk usage: before PETCT_2017 batch 1
# /kaggle/temp free GiB: 1065.08 used GiB: 6997.29 total GiB: 8062.39
# /tmp free GiB: 1065.08 used GiB: 6997.29 total GiB: 8062.39
# /kaggle/working free GiB: 19.5 used GiB: 0.0 total GiB: 19.52
# PETCT_2017 batch 1: cached 6/6 cases, elapsed 0.3 min
#
# Disk usage: after cleanup PETCT_2017 batch 1
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.5 used GiB: 0.0 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 2
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.5 used GiB: 0.0 total GiB: 19.52
# PETCT_2017 batch 2: cached 6/6 cases, elapsed 0.5 min
#
# Disk usage: after cleanup PETCT_2017 batch 2
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.5 used GiB: 0.0 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 3
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.5 used GiB: 0.0 total GiB: 19.52
# PETCT_2017 batch 3: cached 6/6 cases, elapsed 0.8 min
#
# Disk usage: after cleanup PETCT_2017 batch 3
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 19.5 used GiB: 0.01 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 4
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 19.5 used GiB: 0.01 total GiB: 19.52
# PETCT_2017 batch 4: cached 6/6 cases, elapsed 1.0 min
#
# Disk usage: after cleanup PETCT_2017 batch 4
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.5 used GiB: 0.01 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 5
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.5 used GiB: 0.01 total GiB: 19.52
# PETCT_2017 batch 5: cached 6/6 cases, elapsed 1.2 min
#
# Disk usage: after cleanup PETCT_2017 batch 5
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.49 used GiB: 0.01 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 6
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.49 used GiB: 0.01 total GiB: 19.52
# PETCT_2017 batch 6: cached 6/6 cases, elapsed 1.4 min
#
# Disk usage: after cleanup PETCT_2017 batch 6
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.49 used GiB: 0.01 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 7
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.49 used GiB: 0.01 total GiB: 19.52
# PETCT_2017 batch 7: cached 6/6 cases, elapsed 1.7 min
#
# Disk usage: after cleanup PETCT_2017 batch 7
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.49 used GiB: 0.01 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 8
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.49 used GiB: 0.01 total GiB: 19.52
# PETCT_2017 batch 8: cached 6/6 cases, elapsed 1.9 min
#
# Disk usage: after cleanup PETCT_2017 batch 8
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.49 used GiB: 0.01 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 9
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.49 used GiB: 0.01 total GiB: 19.52
# PETCT_2017 batch 9: cached 6/6 cases, elapsed 2.1 min
#
# Disk usage: after cleanup PETCT_2017 batch 9
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.49 used GiB: 0.02 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 10
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.49 used GiB: 0.02 total GiB: 19.52
# PETCT_2017 batch 10: cached 6/6 cases, elapsed 2.3 min
#
# Disk usage: after cleanup PETCT_2017 batch 10
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.49 used GiB: 0.02 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 11
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.49 used GiB: 0.02 total GiB: 19.52
# PETCT_2017 batch 11: cached 6/6 cases, elapsed 2.6 min
#
# Disk usage: after cleanup PETCT_2017 batch 11
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.48 used GiB: 0.02 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 12
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.48 used GiB: 0.02 total GiB: 19.52
# PETCT_2017 batch 12: cached 6/6 cases, elapsed 2.8 min
#
# Disk usage: after cleanup PETCT_2017 batch 12
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.48 used GiB: 0.02 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 13
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.48 used GiB: 0.02 total GiB: 19.52
# PETCT_2017 batch 13: cached 6/6 cases, elapsed 3.1 min
#
# Disk usage: after cleanup PETCT_2017 batch 13
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 19.48 used GiB: 0.02 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 14
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 19.48 used GiB: 0.02 total GiB: 19.52
# PETCT_2017 batch 14: cached 6/6 cases, elapsed 3.3 min
#
# Disk usage: after cleanup PETCT_2017 batch 14
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 19.48 used GiB: 0.02 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 15
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 19.48 used GiB: 0.02 total GiB: 19.52
# PETCT_2017 batch 15: cached 6/6 cases, elapsed 3.6 min
#
# Disk usage: after cleanup PETCT_2017 batch 15
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.48 used GiB: 0.03 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 16
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.48 used GiB: 0.03 total GiB: 19.52
# PETCT_2017 batch 16: cached 6/6 cases, elapsed 3.8 min
#
# Disk usage: after cleanup PETCT_2017 batch 16
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.48 used GiB: 0.03 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 17
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.48 used GiB: 0.03 total GiB: 19.52
# PETCT_2017 batch 17: cached 6/6 cases, elapsed 4.0 min
#
# Disk usage: after cleanup PETCT_2017 batch 17
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.47 used GiB: 0.03 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 18
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.47 used GiB: 0.03 total GiB: 19.52
# PETCT_2017 batch 18: cached 6/6 cases, elapsed 4.2 min
#
# Disk usage: after cleanup PETCT_2017 batch 18
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.47 used GiB: 0.03 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 19
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.47 used GiB: 0.03 total GiB: 19.52
# PETCT_2017 batch 19: cached 6/6 cases, elapsed 4.4 min
#
# Disk usage: after cleanup PETCT_2017 batch 19
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 19.47 used GiB: 0.03 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 20
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 19.47 used GiB: 0.03 total GiB: 19.52
# PETCT_2017 batch 20: cached 6/6 cases, elapsed 4.7 min
#
# Disk usage: after cleanup PETCT_2017 batch 20
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.47 used GiB: 0.03 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 21
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.47 used GiB: 0.03 total GiB: 19.52
# PETCT_2017 batch 21: cached 6/6 cases, elapsed 4.9 min
#
# Disk usage: after cleanup PETCT_2017 batch 21
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.47 used GiB: 0.04 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 22
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.47 used GiB: 0.04 total GiB: 19.52
# PETCT_2017 batch 22: cached 6/6 cases, elapsed 5.1 min
#
# Disk usage: after cleanup PETCT_2017 batch 22
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 19.47 used GiB: 0.04 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 23
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 19.47 used GiB: 0.04 total GiB: 19.52
# PETCT_2017 batch 23: cached 6/6 cases, elapsed 5.4 min
#
# Disk usage: after cleanup PETCT_2017 batch 23
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.46 used GiB: 0.04 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 24
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.46 used GiB: 0.04 total GiB: 19.52
# PETCT_2017 batch 24: cached 6/6 cases, elapsed 5.7 min
#
# Disk usage: after cleanup PETCT_2017 batch 24
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.46 used GiB: 0.04 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 25
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.46 used GiB: 0.04 total GiB: 19.52
# PETCT_2017 batch 25: cached 6/6 cases, elapsed 5.9 min
#
# Disk usage: after cleanup PETCT_2017 batch 25
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.46 used GiB: 0.04 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 26
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.46 used GiB: 0.04 total GiB: 19.52
# PETCT_2017 batch 26: cached 6/6 cases, elapsed 6.2 min
#
# Disk usage: after cleanup PETCT_2017 batch 26
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.46 used GiB: 0.04 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 27
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.46 used GiB: 0.04 total GiB: 19.52
# PETCT_2017 batch 27: cached 6/6 cases, elapsed 6.4 min
#
# Disk usage: after cleanup PETCT_2017 batch 27
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.46 used GiB: 0.05 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 28
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.46 used GiB: 0.05 total GiB: 19.52
# PETCT_2017 batch 28: cached 6/6 cases, elapsed 6.7 min
#
# Disk usage: after cleanup PETCT_2017 batch 28
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.46 used GiB: 0.05 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 29
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.46 used GiB: 0.05 total GiB: 19.52
# PETCT_2017 batch 29: cached 6/6 cases, elapsed 6.9 min
#
# Disk usage: after cleanup PETCT_2017 batch 29
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.45 used GiB: 0.05 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 30
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.45 used GiB: 0.05 total GiB: 19.52
# PETCT_2017 batch 30: cached 6/6 cases, elapsed 7.2 min
#
# Disk usage: after cleanup PETCT_2017 batch 30
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.45 used GiB: 0.05 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 31
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.45 used GiB: 0.05 total GiB: 19.52
# PETCT_2017 batch 31: cached 6/6 cases, elapsed 7.5 min
#
# Disk usage: after cleanup PETCT_2017 batch 31
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.45 used GiB: 0.05 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 32
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.45 used GiB: 0.05 total GiB: 19.52
# PETCT_2017 batch 32: cached 6/6 cases, elapsed 7.8 min
#
# Disk usage: after cleanup PETCT_2017 batch 32
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.45 used GiB: 0.05 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 33
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.45 used GiB: 0.05 total GiB: 19.52
# PETCT_2017 batch 33: cached 6/6 cases, elapsed 8.1 min
#
# Disk usage: after cleanup PETCT_2017 batch 33
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.45 used GiB: 0.06 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 34
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.45 used GiB: 0.06 total GiB: 19.52
# PETCT_2017 batch 34: cached 6/6 cases, elapsed 8.3 min
#
# Disk usage: after cleanup PETCT_2017 batch 34
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.45 used GiB: 0.06 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 35
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.45 used GiB: 0.06 total GiB: 19.52
# PETCT_2017 batch 35: cached 6/6 cases, elapsed 8.5 min
#
# Disk usage: after cleanup PETCT_2017 batch 35
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.44 used GiB: 0.06 total GiB: 19.52
#
# Disk usage: before PETCT_2017 batch 36
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.44 used GiB: 0.06 total GiB: 19.52
# PETCT_2017 batch 36: cached 5/5 cases, elapsed 8.7 min
#
# Disk usage: after cleanup PETCT_2017 batch 36
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.44 used GiB: 0.06 total GiB: 19.52
# PETCT_2018: parts=14, marker=PETCT_2018.zipraw
#
# Disk usage: before PETCT_2018 batch 1
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.44 used GiB: 0.06 total GiB: 19.52
# PETCT_2018 batch 1: cached 6/6 cases, elapsed 9.0 min
#
# Disk usage: after cleanup PETCT_2018 batch 1
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.44 used GiB: 0.06 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 2
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.44 used GiB: 0.06 total GiB: 19.52
# PETCT_2018 batch 2: cached 6/6 cases, elapsed 9.2 min
#
# Disk usage: after cleanup PETCT_2018 batch 2
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.44 used GiB: 0.06 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 3
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.44 used GiB: 0.06 total GiB: 19.52
# PETCT_2018 batch 3: cached 6/6 cases, elapsed 9.5 min
#
# Disk usage: after cleanup PETCT_2018 batch 3
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.44 used GiB: 0.07 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 4
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.44 used GiB: 0.07 total GiB: 19.52
# PETCT_2018 batch 4: cached 6/6 cases, elapsed 9.7 min
#
# Disk usage: after cleanup PETCT_2018 batch 4
# /kaggle/temp free GiB: 1064.87 used GiB: 6997.5 total GiB: 8062.39
# /tmp free GiB: 1064.87 used GiB: 6997.5 total GiB: 8062.39
# /kaggle/working free GiB: 19.44 used GiB: 0.07 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 5
# /kaggle/temp free GiB: 1064.87 used GiB: 6997.5 total GiB: 8062.39
# /tmp free GiB: 1064.87 used GiB: 6997.5 total GiB: 8062.39
# /kaggle/working free GiB: 19.44 used GiB: 0.07 total GiB: 19.52
# PETCT_2018 batch 5: cached 6/6 cases, elapsed 9.9 min
#
# Disk usage: after cleanup PETCT_2018 batch 5
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.43 used GiB: 0.07 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 6
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.43 used GiB: 0.07 total GiB: 19.52
# PETCT_2018 batch 6: cached 6/6 cases, elapsed 10.2 min
#
# Disk usage: after cleanup PETCT_2018 batch 6
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.43 used GiB: 0.07 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 7
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.43 used GiB: 0.07 total GiB: 19.52
# PETCT_2018 batch 7: cached 6/6 cases, elapsed 10.4 min
#
# Disk usage: after cleanup PETCT_2018 batch 7
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.43 used GiB: 0.07 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 8
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.43 used GiB: 0.07 total GiB: 19.52
# PETCT_2018 batch 8: cached 6/6 cases, elapsed 10.7 min
#
# Disk usage: after cleanup PETCT_2018 batch 8
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.43 used GiB: 0.07 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 9
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.43 used GiB: 0.07 total GiB: 19.52
# PETCT_2018 batch 9: cached 6/6 cases, elapsed 11.0 min
#
# Disk usage: after cleanup PETCT_2018 batch 9
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.43 used GiB: 0.08 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 10
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.43 used GiB: 0.08 total GiB: 19.52
# PETCT_2018 batch 10: cached 6/6 cases, elapsed 11.3 min
#
# Disk usage: after cleanup PETCT_2018 batch 10
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.43 used GiB: 0.08 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 11
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.43 used GiB: 0.08 total GiB: 19.52
# PETCT_2018 batch 11: cached 6/6 cases, elapsed 11.6 min
#
# Disk usage: after cleanup PETCT_2018 batch 11
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.42 used GiB: 0.08 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 12
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.42 used GiB: 0.08 total GiB: 19.52
# PETCT_2018 batch 12: cached 6/6 cases, elapsed 11.8 min
#
# Disk usage: after cleanup PETCT_2018 batch 12
# /kaggle/temp free GiB: 1064.86 used GiB: 6997.51 total GiB: 8062.39
# /tmp free GiB: 1064.86 used GiB: 6997.51 total GiB: 8062.39
# /kaggle/working free GiB: 19.42 used GiB: 0.08 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 13
# /kaggle/temp free GiB: 1064.86 used GiB: 6997.51 total GiB: 8062.39
# /tmp free GiB: 1064.86 used GiB: 6997.51 total GiB: 8062.39
# /kaggle/working free GiB: 19.42 used GiB: 0.08 total GiB: 19.52
# PETCT_2018 batch 13: cached 6/6 cases, elapsed 12.1 min
#
# Disk usage: after cleanup PETCT_2018 batch 13
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.42 used GiB: 0.08 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 14
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.42 used GiB: 0.08 total GiB: 19.52
# PETCT_2018 batch 14: cached 6/6 cases, elapsed 12.4 min
#
# Disk usage: after cleanup PETCT_2018 batch 14
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.42 used GiB: 0.08 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 15
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.42 used GiB: 0.08 total GiB: 19.52
# PETCT_2018 batch 15: cached 6/6 cases, elapsed 12.6 min
#
# Disk usage: after cleanup PETCT_2018 batch 15
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.42 used GiB: 0.09 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 16
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.42 used GiB: 0.09 total GiB: 19.52
# PETCT_2018 batch 16: cached 6/6 cases, elapsed 12.9 min
#
# Disk usage: after cleanup PETCT_2018 batch 16
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.42 used GiB: 0.09 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 17
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.42 used GiB: 0.09 total GiB: 19.52
# PETCT_2018 batch 17: cached 6/6 cases, elapsed 13.2 min
#
# Disk usage: after cleanup PETCT_2018 batch 17
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.41 used GiB: 0.09 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 18
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.41 used GiB: 0.09 total GiB: 19.52
# PETCT_2018 batch 18: cached 6/6 cases, elapsed 13.4 min
#
# Disk usage: after cleanup PETCT_2018 batch 18
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.41 used GiB: 0.09 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 19
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.41 used GiB: 0.09 total GiB: 19.52
# PETCT_2018 batch 19: cached 6/6 cases, elapsed 13.6 min
#
# Disk usage: after cleanup PETCT_2018 batch 19
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.41 used GiB: 0.09 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 20
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.41 used GiB: 0.09 total GiB: 19.52
# PETCT_2018 batch 20: cached 6/6 cases, elapsed 13.9 min
#
# Disk usage: after cleanup PETCT_2018 batch 20
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.41 used GiB: 0.09 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 21
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.41 used GiB: 0.09 total GiB: 19.52
# PETCT_2018 batch 21: cached 6/6 cases, elapsed 14.1 min
#
# Disk usage: after cleanup PETCT_2018 batch 21
# /kaggle/temp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /tmp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /kaggle/working free GiB: 19.41 used GiB: 0.1 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 22
# /kaggle/temp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /tmp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /kaggle/working free GiB: 19.41 used GiB: 0.1 total GiB: 19.52
# PETCT_2018 batch 22: cached 6/6 cases, elapsed 14.3 min
#
# Disk usage: after cleanup PETCT_2018 batch 22
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.4 used GiB: 0.1 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 23
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.4 used GiB: 0.1 total GiB: 19.52
# PETCT_2018 batch 23: cached 6/6 cases, elapsed 14.6 min
#
# Disk usage: after cleanup PETCT_2018 batch 23
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.4 used GiB: 0.1 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 24
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.4 used GiB: 0.1 total GiB: 19.52
# PETCT_2018 batch 24: cached 6/6 cases, elapsed 14.8 min
#
# Disk usage: after cleanup PETCT_2018 batch 24
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.4 used GiB: 0.1 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 25
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.4 used GiB: 0.1 total GiB: 19.52
# PETCT_2018 batch 25: cached 6/6 cases, elapsed 15.1 min
#
# Disk usage: after cleanup PETCT_2018 batch 25
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.4 used GiB: 0.1 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 26
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.4 used GiB: 0.1 total GiB: 19.52
# PETCT_2018 batch 26: cached 6/6 cases, elapsed 15.3 min
#
# Disk usage: after cleanup PETCT_2018 batch 26
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.4 used GiB: 0.1 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 27
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.4 used GiB: 0.1 total GiB: 19.52
# PETCT_2018 batch 27: cached 6/6 cases, elapsed 15.5 min
#
# Disk usage: after cleanup PETCT_2018 batch 27
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.4 used GiB: 0.11 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 28
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.4 used GiB: 0.11 total GiB: 19.52
# PETCT_2018 batch 28: cached 6/6 cases, elapsed 16.0 min
#
# Disk usage: after cleanup PETCT_2018 batch 28
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.39 used GiB: 0.11 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 29
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.39 used GiB: 0.11 total GiB: 19.52
# PETCT_2018 batch 29: cached 6/6 cases, elapsed 16.2 min
#
# Disk usage: after cleanup PETCT_2018 batch 29
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.39 used GiB: 0.11 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 30
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.39 used GiB: 0.11 total GiB: 19.52
# PETCT_2018 batch 30: cached 6/6 cases, elapsed 16.5 min
#
# Disk usage: after cleanup PETCT_2018 batch 30
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.39 used GiB: 0.11 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 31
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.39 used GiB: 0.11 total GiB: 19.52
# PETCT_2018 batch 31: cached 6/6 cases, elapsed 16.8 min
#
# Disk usage: after cleanup PETCT_2018 batch 31
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.39 used GiB: 0.11 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 32
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.39 used GiB: 0.11 total GiB: 19.52
# PETCT_2018 batch 32: cached 6/6 cases, elapsed 17.0 min
#
# Disk usage: after cleanup PETCT_2018 batch 32
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.39 used GiB: 0.11 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 33
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.39 used GiB: 0.11 total GiB: 19.52
# PETCT_2018 batch 33: cached 6/6 cases, elapsed 17.2 min
#
# Disk usage: after cleanup PETCT_2018 batch 33
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.39 used GiB: 0.12 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 34
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.39 used GiB: 0.12 total GiB: 19.52
# PETCT_2018 batch 34: cached 6/6 cases, elapsed 17.5 min
#
# Disk usage: after cleanup PETCT_2018 batch 34
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.38 used GiB: 0.12 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 35
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.38 used GiB: 0.12 total GiB: 19.52
# PETCT_2018 batch 35: cached 6/6 cases, elapsed 17.8 min
#
# Disk usage: after cleanup PETCT_2018 batch 35
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.38 used GiB: 0.12 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 36
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.38 used GiB: 0.12 total GiB: 19.52
# PETCT_2018 batch 36: cached 6/6 cases, elapsed 18.0 min
#
# Disk usage: after cleanup PETCT_2018 batch 36
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.38 used GiB: 0.12 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 37
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.38 used GiB: 0.12 total GiB: 19.52
# PETCT_2018 batch 37: cached 6/6 cases, elapsed 18.3 min
#
# Disk usage: after cleanup PETCT_2018 batch 37
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.38 used GiB: 0.12 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 38
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.38 used GiB: 0.12 total GiB: 19.52
# PETCT_2018 batch 38: cached 6/6 cases, elapsed 18.5 min
#
# Disk usage: after cleanup PETCT_2018 batch 38
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.38 used GiB: 0.12 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 39
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.38 used GiB: 0.12 total GiB: 19.52
# PETCT_2018 batch 39: cached 6/6 cases, elapsed 18.7 min
#
# Disk usage: after cleanup PETCT_2018 batch 39
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.38 used GiB: 0.13 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 40
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.38 used GiB: 0.13 total GiB: 19.52
# PETCT_2018 batch 40: cached 6/6 cases, elapsed 19.0 min
#
# Disk usage: after cleanup PETCT_2018 batch 40
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 19.37 used GiB: 0.13 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 41
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 19.37 used GiB: 0.13 total GiB: 19.52
# PETCT_2018 batch 41: cached 6/6 cases, elapsed 19.2 min
#
# Disk usage: after cleanup PETCT_2018 batch 41
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 19.37 used GiB: 0.13 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 42
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 19.37 used GiB: 0.13 total GiB: 19.52
# PETCT_2018 batch 42: cached 6/6 cases, elapsed 19.5 min
#
# Disk usage: after cleanup PETCT_2018 batch 42
# /kaggle/temp free GiB: 1064.87 used GiB: 6997.5 total GiB: 8062.39
# /tmp free GiB: 1064.87 used GiB: 6997.5 total GiB: 8062.39
# /kaggle/working free GiB: 19.37 used GiB: 0.13 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 43
# /kaggle/temp free GiB: 1064.87 used GiB: 6997.5 total GiB: 8062.39
# /tmp free GiB: 1064.87 used GiB: 6997.5 total GiB: 8062.39
# /kaggle/working free GiB: 19.37 used GiB: 0.13 total GiB: 19.52
# PETCT_2018 batch 43: cached 6/6 cases, elapsed 19.7 min
#
# Disk usage: after cleanup PETCT_2018 batch 43
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 19.37 used GiB: 0.13 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 44
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 19.37 used GiB: 0.13 total GiB: 19.52
# PETCT_2018 batch 44: cached 6/6 cases, elapsed 20.0 min
#
# Disk usage: after cleanup PETCT_2018 batch 44
# /kaggle/temp free GiB: 1064.94 used GiB: 6997.43 total GiB: 8062.39
# /tmp free GiB: 1064.94 used GiB: 6997.43 total GiB: 8062.39
# /kaggle/working free GiB: 19.37 used GiB: 0.13 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 45
# /kaggle/temp free GiB: 1064.94 used GiB: 6997.43 total GiB: 8062.39
# /tmp free GiB: 1064.94 used GiB: 6997.43 total GiB: 8062.39
# /kaggle/working free GiB: 19.37 used GiB: 0.13 total GiB: 19.52
# PETCT_2018 batch 45: cached 6/6 cases, elapsed 20.2 min
#
# Disk usage: after cleanup PETCT_2018 batch 45
# /kaggle/temp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /tmp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /kaggle/working free GiB: 19.37 used GiB: 0.14 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 46
# /kaggle/temp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /tmp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /kaggle/working free GiB: 19.37 used GiB: 0.14 total GiB: 19.52
# PETCT_2018 batch 46: cached 6/6 cases, elapsed 20.4 min
#
# Disk usage: after cleanup PETCT_2018 batch 46
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 19.36 used GiB: 0.14 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 47
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 19.36 used GiB: 0.14 total GiB: 19.52
# PETCT_2018 batch 47: cached 6/6 cases, elapsed 20.7 min
#
# Disk usage: after cleanup PETCT_2018 batch 47
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.36 used GiB: 0.14 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 48
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.36 used GiB: 0.14 total GiB: 19.52
# PETCT_2018 batch 48: cached 6/6 cases, elapsed 20.9 min
#
# Disk usage: after cleanup PETCT_2018 batch 48
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.36 used GiB: 0.14 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 49
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.36 used GiB: 0.14 total GiB: 19.52
# PETCT_2018 batch 49: cached 6/6 cases, elapsed 21.2 min
#
# Disk usage: after cleanup PETCT_2018 batch 49
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.36 used GiB: 0.14 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 50
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.36 used GiB: 0.14 total GiB: 19.52
# PETCT_2018 batch 50: cached 6/6 cases, elapsed 21.4 min
#
# Disk usage: after cleanup PETCT_2018 batch 50
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.36 used GiB: 0.14 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 51
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.36 used GiB: 0.14 total GiB: 19.52
# PETCT_2018 batch 51: cached 6/6 cases, elapsed 21.7 min
#
# Disk usage: after cleanup PETCT_2018 batch 51
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.36 used GiB: 0.15 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 52
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.36 used GiB: 0.15 total GiB: 19.52
# PETCT_2018 batch 52: cached 6/6 cases, elapsed 21.9 min
#
# Disk usage: after cleanup PETCT_2018 batch 52
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.35 used GiB: 0.15 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 53
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.35 used GiB: 0.15 total GiB: 19.52
# PETCT_2018 batch 53: cached 6/6 cases, elapsed 22.1 min
#
# Disk usage: after cleanup PETCT_2018 batch 53
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.35 used GiB: 0.15 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 54
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 19.35 used GiB: 0.15 total GiB: 19.52
# PETCT_2018 batch 54: cached 6/6 cases, elapsed 22.4 min
#
# Disk usage: after cleanup PETCT_2018 batch 54
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.35 used GiB: 0.15 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 55
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 19.35 used GiB: 0.15 total GiB: 19.52
# PETCT_2018 batch 55: cached 6/6 cases, elapsed 22.6 min
#
# Disk usage: after cleanup PETCT_2018 batch 55
# /kaggle/temp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /tmp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /kaggle/working free GiB: 19.35 used GiB: 0.15 total GiB: 19.52
#
# Disk usage: before PETCT_2018 batch 56
# ...
# /kaggle/working free GiB: 18.78 used GiB: 0.72 total GiB: 19.52
# PETCT_2023_3 batch 51: cached 6/6 cases, elapsed 95.8 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 51
# /kaggle/temp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /tmp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /kaggle/working free GiB: 18.78 used GiB: 0.73 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 52
# /kaggle/temp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /tmp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /kaggle/working free GiB: 18.78 used GiB: 0.73 total GiB: 19.52
# PETCT_2023_3 batch 52: cached 6/6 cases, elapsed 96.0 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 52
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.77 used GiB: 0.73 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 53
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.77 used GiB: 0.73 total GiB: 19.52
# PETCT_2023_3 batch 53: cached 6/6 cases, elapsed 96.2 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 53
# /kaggle/temp free GiB: 1064.79 used GiB: 6997.58 total GiB: 8062.39
# /tmp free GiB: 1064.79 used GiB: 6997.58 total GiB: 8062.39
# /kaggle/working free GiB: 18.77 used GiB: 0.73 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 54
# /kaggle/temp free GiB: 1064.79 used GiB: 6997.58 total GiB: 8062.39
# /tmp free GiB: 1064.79 used GiB: 6997.58 total GiB: 8062.39
# /kaggle/working free GiB: 18.77 used GiB: 0.73 total GiB: 19.52
# PETCT_2023_3 batch 54: cached 6/6 cases, elapsed 96.4 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 54
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 18.77 used GiB: 0.73 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 55
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 18.77 used GiB: 0.73 total GiB: 19.52
# PETCT_2023_3 batch 55: cached 6/6 cases, elapsed 96.6 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 55
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 18.77 used GiB: 0.73 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 56
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 18.77 used GiB: 0.73 total GiB: 19.52
# PETCT_2023_3 batch 56: cached 6/6 cases, elapsed 96.8 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 56
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.77 used GiB: 0.73 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 57
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.77 used GiB: 0.73 total GiB: 19.52
# PETCT_2023_3 batch 57: cached 6/6 cases, elapsed 97.0 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 57
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.77 used GiB: 0.74 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 58
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.77 used GiB: 0.74 total GiB: 19.52
# PETCT_2023_3 batch 58: cached 6/6 cases, elapsed 97.2 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 58
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.76 used GiB: 0.74 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 59
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.76 used GiB: 0.74 total GiB: 19.52
# PETCT_2023_3 batch 59: cached 6/6 cases, elapsed 97.4 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 59
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.76 used GiB: 0.74 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 60
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.76 used GiB: 0.74 total GiB: 19.52
# PETCT_2023_3 batch 60: cached 6/6 cases, elapsed 97.6 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 60
# /kaggle/temp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /tmp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /kaggle/working free GiB: 18.76 used GiB: 0.74 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 61
# /kaggle/temp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /tmp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /kaggle/working free GiB: 18.76 used GiB: 0.74 total GiB: 19.52
# PETCT_2023_3 batch 61: cached 6/6 cases, elapsed 97.8 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 61
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 18.76 used GiB: 0.74 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 62
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 18.76 used GiB: 0.74 total GiB: 19.52
# PETCT_2023_3 batch 62: cached 6/6 cases, elapsed 98.0 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 62
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 18.76 used GiB: 0.74 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 63
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 18.76 used GiB: 0.74 total GiB: 19.52
# PETCT_2023_3 batch 63: cached 6/6 cases, elapsed 98.2 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 63
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.76 used GiB: 0.75 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 64
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.76 used GiB: 0.75 total GiB: 19.52
# PETCT_2023_3 batch 64: cached 6/6 cases, elapsed 98.5 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 64
# /kaggle/temp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /tmp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /kaggle/working free GiB: 18.75 used GiB: 0.75 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 65
# /kaggle/temp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /tmp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /kaggle/working free GiB: 18.75 used GiB: 0.75 total GiB: 19.52
# PETCT_2023_3 batch 65: cached 6/6 cases, elapsed 98.9 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 65
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 18.75 used GiB: 0.75 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 66
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 18.75 used GiB: 0.75 total GiB: 19.52
# PETCT_2023_3 batch 66: cached 6/6 cases, elapsed 99.1 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 66
# /kaggle/temp free GiB: 1064.94 used GiB: 6997.43 total GiB: 8062.39
# /tmp free GiB: 1064.94 used GiB: 6997.43 total GiB: 8062.39
# /kaggle/working free GiB: 18.75 used GiB: 0.75 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 67
# /kaggle/temp free GiB: 1064.94 used GiB: 6997.43 total GiB: 8062.39
# /tmp free GiB: 1064.94 used GiB: 6997.43 total GiB: 8062.39
# /kaggle/working free GiB: 18.75 used GiB: 0.75 total GiB: 19.52
# PETCT_2023_3 batch 67: cached 6/6 cases, elapsed 99.3 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 67
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 18.75 used GiB: 0.75 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 68
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 18.75 used GiB: 0.75 total GiB: 19.52
# PETCT_2023_3 batch 68: cached 6/6 cases, elapsed 99.5 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 68
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.75 used GiB: 0.75 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 69
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.75 used GiB: 0.75 total GiB: 19.52
# PETCT_2023_3 batch 69: cached 6/6 cases, elapsed 99.7 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 69
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 18.75 used GiB: 0.76 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 70
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 18.75 used GiB: 0.76 total GiB: 19.52
# PETCT_2023_3 batch 70: cached 6/6 cases, elapsed 100.0 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 70
# /kaggle/temp free GiB: 1064.93 used GiB: 6997.45 total GiB: 8062.39
# /tmp free GiB: 1064.93 used GiB: 6997.45 total GiB: 8062.39
# /kaggle/working free GiB: 18.74 used GiB: 0.76 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 71
# /kaggle/temp free GiB: 1064.93 used GiB: 6997.45 total GiB: 8062.39
# /tmp free GiB: 1064.93 used GiB: 6997.45 total GiB: 8062.39
# /kaggle/working free GiB: 18.74 used GiB: 0.76 total GiB: 19.52
# PETCT_2023_3 batch 71: cached 6/6 cases, elapsed 100.2 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 71
# /kaggle/temp free GiB: 1064.92 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.92 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.74 used GiB: 0.76 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 72
# /kaggle/temp free GiB: 1064.92 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.92 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.74 used GiB: 0.76 total GiB: 19.52
# PETCT_2023_3 batch 72: cached 6/6 cases, elapsed 100.4 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 72
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.74 used GiB: 0.76 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 73
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.74 used GiB: 0.76 total GiB: 19.52
# PETCT_2023_3 batch 73: cached 6/6 cases, elapsed 100.6 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 73
# /kaggle/temp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /tmp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /kaggle/working free GiB: 18.74 used GiB: 0.76 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 74
# /kaggle/temp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /tmp free GiB: 1064.92 used GiB: 6997.45 total GiB: 8062.39
# /kaggle/working free GiB: 18.74 used GiB: 0.76 total GiB: 19.52
# PETCT_2023_3 batch 74: cached 6/6 cases, elapsed 100.8 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 74
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.74 used GiB: 0.76 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 75
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.74 used GiB: 0.76 total GiB: 19.52
# PETCT_2023_3 batch 75: cached 6/6 cases, elapsed 101.0 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 75
# /kaggle/temp free GiB: 1064.88 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.88 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 18.74 used GiB: 0.77 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 76
# /kaggle/temp free GiB: 1064.88 used GiB: 6997.49 total GiB: 8062.39
# /tmp free GiB: 1064.88 used GiB: 6997.49 total GiB: 8062.39
# /kaggle/working free GiB: 18.74 used GiB: 0.77 total GiB: 19.52
# PETCT_2023_3 batch 76: cached 6/6 cases, elapsed 101.2 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 76
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.73 used GiB: 0.77 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 77
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.73 used GiB: 0.77 total GiB: 19.52
# PETCT_2023_3 batch 77: cached 6/6 cases, elapsed 101.4 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 77
# /kaggle/temp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /tmp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /kaggle/working free GiB: 18.73 used GiB: 0.77 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 78
# /kaggle/temp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /tmp free GiB: 1064.93 used GiB: 6997.44 total GiB: 8062.39
# /kaggle/working free GiB: 18.73 used GiB: 0.77 total GiB: 19.52
# PETCT_2023_3 batch 78: cached 6/6 cases, elapsed 101.6 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 78
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 18.73 used GiB: 0.77 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 79
# /kaggle/temp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /tmp free GiB: 1064.9 used GiB: 6997.47 total GiB: 8062.39
# /kaggle/working free GiB: 18.73 used GiB: 0.77 total GiB: 19.52
# PETCT_2023_3 batch 79: cached 6/6 cases, elapsed 101.9 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 79
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.73 used GiB: 0.77 total GiB: 19.52
#
# Disk usage: before PETCT_2023_3 batch 80
# /kaggle/temp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /tmp free GiB: 1064.91 used GiB: 6997.46 total GiB: 8062.39
# /kaggle/working free GiB: 18.73 used GiB: 0.77 total GiB: 19.52
# PETCT_2023_3 batch 80: cached 3/3 cases, elapsed 102.0 min
#
# Disk usage: after cleanup PETCT_2023_3 batch 80
# /kaggle/temp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /tmp free GiB: 1064.89 used GiB: 6997.48 total GiB: 8062.39
# /kaggle/working free GiB: 18.73 used GiB: 0.77 total GiB: 19.52
#   clean_split  cache_ok  cases
# 0        test      True    413
# 1       train      True   1931
# 2  validation      True    413
# Saved cache: /kaggle/working/vimedpet_q1_outputs/01_cache

# %%
cache_index = pd.read_csv(CACHE_DIR / "q1_cache_index.csv")
ok_rows = cache_index[cache_index["cache_ok"] == True].head(4)
if len(ok_rows):
    fig, axes = plt.subplots(len(ok_rows), 6, figsize=(12, 2.2 * len(ok_rows)), constrained_layout=True)
    if len(ok_rows) == 1:
        axes = np.array([axes])
    titles = ["CT 35%", "CT 50%", "CT 65%", "PET axial MIP", "PET coronal MIP", "PET sagittal MIP"]
    for r, row in enumerate(ok_rows.itertuples(index=False)):
        img = arr[int(row.row_index)]
        for c in range(6):
            axes[r, c].imshow(img[c], cmap="gray" if c < 3 else "magma")
            axes[r, c].set_title(titles[c], fontsize=8)
            axes[r, c].axis("off")
        axes[r, 0].set_ylabel(str(row.case_id), fontsize=8)
    preview_path = CACHE_DIR / "q1_25d_cache_preview.png"
    fig.savefig(preview_path, dpi=170, bbox_inches="tight")
    plt.show()
    print("Preview:", preview_path)
# Out:
# Preview: /kaggle/working/vimedpet_q1_outputs/01_cache/q1_25d_cache_preview.png
